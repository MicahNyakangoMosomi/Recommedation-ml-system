# %%
fees = {
    "ann":3033,
    "micah":13456,
    "abel":7890,
    "brian":3456,
    "bonface":1234,
    "mary":5673,
    "abigeal":2689,
    "Maggy":6789,
    "Sherlyne":5609
}

max_ = max(fees,key=fees.get)
print(max_)
# Out:
# micah
